# %% [markdown]
# Name - Ranvijay Patel<br/>
# ROLL No - 1901156<br/>
# Email - ranvijay.amarnath@iiitg.ac.in<br/>

# %% [markdown]
# # 1. Logic gate Implement using perceptron (AND, OR, Nand)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import warnings
from matplotlib import pyplot as plt
warnings.filterwarnings('default')
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score, classification_report

# %%
def predict(x_test, y_test, weight):
  # This function will take the weight of the trained model and takes decission based on the threshold value
  # Add Intercept
  # x_test = add_intercept(x_test)
  y_pred = np.ones(y_test.shape[0])
  hypothesis = np.dot(x_test, weight.T)
  for i in range(0, hypothesis.shape[0]):
    if (hypothesis[i]<0.5):
      y_pred[i] = 0
    if (hypothesis[i]>=0.5):
      y_pred[i] = 1
  test_acc = accuracy_score(y_test, y_pred)
  return test_acc

# %%
def new_predict(x_test, y_test, weight):
  # This function will take the weight of the trained model and takes decission based on the threshold value
  # Add Intercept
  x_test = add_intercept(x_test)
  y_pred = np.ones(y_test.shape[0])
  hypothesis = np.dot(x_test, weight.T)
  for i in range(0, hypothesis.shape[0]):
    if (hypothesis[i]<0.5):
      y_pred[i] = 0
    if (hypothesis[i]>=0.5):
      y_pred[i] = 1
  test_acc = accuracy_score(y_test, y_pred)
  precision = precision_score(y_test, y_pred)*100
  recall = recall_score(y_test, y_pred)*100
  f1 = f1_score(y_test, y_pred)*100
  print("Training Accuracy: ", test_acc)
  print("Prescission Score:", precision)
  print("Recall Score : ", recall) 
  print('F1 Score : ', f1)
  print('Confusion Matrix : \n' + str(confusion_matrix(y_test, y_pred)))
  print("Classification Report for 3-classes: ")
  print(classification_report(y_test, y_pred))
  # calculate the overall accuracy
  # print the confussion matrix
  # print the classification report
  return test_acc

# %%
def add_intercept(x):
  intercept = np.ones((x.shape[0], 1))
  return np.concatenate((intercept, x), axis=1)
def perceptron(x_train, y_train, same_weight = False):
  # it uses only the threshold function (basic perceptron)
  # add intercept 
  x_train = add_intercept(x_train)
  used_index = []
  weight = np.zeros(x_train.shape[1])# Intialize the weight randomly
  if (same_weight == True): # If we need to do the same weight initilization
    random.seed(10)
  for i in range(0, x_train.shape[1]):
    weight[i] = 0.1 # random.uniform(0, 0.1)
  converged  = True
  x_train, y_train = shuffle(x_train, y_train)  # shuffel the training sample
  index = random.randint(0, x_train.shape[0]-1)
  epoch = 1
  while converged:
    print("Epoch:", epoch)
    hypothesis = np.dot(x_train[index], weight.T)
    if (y_train[index]==1 and hypothesis<0):
      # update the weight
      # w = w + x
      weight = weight + x_train[index]
    if (y_train[index]==0 and hypothesis>=0):
      # update the weight
      # w = w - x
      weight = weight - x_train[index]
    index = random.randint(0, x_train.shape[0]-1)     # pick the random sample
    used_index.append(index)
    if (len(set(used_index)) == x_train.shape[0]):
      # now check what is the accuracy now
      score = predict(x_train, y_train, weight)
      if (score*100==100):
        print("Succefully Converged:")
        converged = False
    epoch = epoch + 1
  return weight

# %% [markdown]
# 1.1. OR GATE

# %%
x_train = np.array([[0, 1], [1, 1], [0, 0], [1, 0]])
y_train = np.array([1, 1, 0, 1])
weight  = perceptron(x_train, y_train, same_weight = False)
test_arr = new_predict(x_train, y_train, weight)
# Out:
# Epoch: 1
# Epoch: 2
# Epoch: 3
# Epoch: 4
# Epoch: 5
# Epoch: 6
# Succefully Converged:
# Training Accuracy:  1.0
# Prescission Score: 100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[1 0]
#  [0 3]]
# Classification Report for 3-classes:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4

# %% [markdown]
# 1.2. AND GATE

# %%
x_train = np.array([[0, 1], [1, 1], [0, 0], [1, 0]])
y_train = np.array([0, 1, 0, 0])
weight  = perceptron(x_train, y_train, same_weight = False)
test_arr = new_predict(x_train, y_train, weight)
# Out:
# Epoch: 1
# Epoch: 2
# Epoch: 3
# Epoch: 4
# Epoch: 5
# Epoch: 6
# Epoch: 7
# Epoch: 8
# Epoch: 9
# Epoch: 10
# Epoch: 11
# Epoch: 12
# Epoch: 13
# Epoch: 14
# Epoch: 15
# Epoch: 16
# Epoch: 17
# Epoch: 18
# Epoch: 19
# Epoch: 20
# Succefully Converged:
# Training Accuracy:  1.0
# Prescission Score: 100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[3 0]
#  [0 1]]
# Classification Report for 3-classes:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4

# %% [markdown]
# 1.3. Nand Gate

# %%
x_train = np.array([[0, 1], [1, 1], [0, 0], [1, 0]])
y_train = np.array([1, 0, 1, 1])
weight  = perceptron(x_train, y_train, same_weight = False)
test_arr = new_predict(x_train, y_train, weight)
# Out:
# Epoch: 1
# Epoch: 2
# Epoch: 3
# Epoch: 4
# Epoch: 5
# Epoch: 6
# Epoch: 7
# Epoch: 8
# Epoch: 9
# Epoch: 10
# Epoch: 11
# Epoch: 12
# Epoch: 13
# Epoch: 14
# Epoch: 15
# Epoch: 16
# Epoch: 17
# Epoch: 18
# Epoch: 19
# Epoch: 20
# Epoch: 21
# Epoch: 22
# Epoch: 23
# Epoch: 24
# Epoch: 25
# Epoch: 26
# Epoch: 27
# Epoch: 28
# Epoch: 29
# Epoch: 30
# Epoch: 31
# Succefully Converged:
# Training Accuracy:  1.0
# Prescission Score: 100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[1 0]
#  [0 3]]
# Classification Report for 3-classes:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4

# %% [markdown]
# 1.4. XOR Gate

# %%
def add_intercept(x):
  intercept = np.ones((x.shape[0], 1))
  return np.concatenate((intercept, x), axis=1)
def perceptron(x_train, y_train, same_weight = False):
  # it uses only the threshold function (basic perceptron)
  # add intercept 
  x_train = add_intercept(x_train)
  used_index = []
  weight = np.zeros(x_train.shape[1])# Intialize the weight randomly
  if (same_weight == True): # If we need to do the same weight initilization
    random.seed(10)
  for i in range(0, x_train.shape[1]):
    weight[i] = 0.1 # random.uniform(0, 0.1)
  converged  = True
  x_train, y_train = shuffle(x_train, y_train)  # shuffel the training sample
  index = random.randint(0, x_train.shape[0]-1)
  epoch = 1
  while converged:
    print("Epoch:", epoch)
    hypothesis = np.dot(x_train[index], weight.T)
    if (y_train[index]==1 and hypothesis<0):
      # update the weight
      # w = w + x
      weight = weight + x_train[index]
    if (y_train[index]==0 and hypothesis>=0):
      # update the weight
      # w = w - x
      weight = weight - x_train[index]
    index = random.randint(0, x_train.shape[0]-1)     # pick the random sample
    used_index.append(index)
    if (len(set(used_index)) == x_train.shape[0]):
      # now check what is the accuracy now
      score = predict(x_train, y_train, weight)
      if (score*100==75):
        print("Succefully Converged:")
        converged = False
    epoch = epoch + 1
  return weight

# %%
x_train = np.array([[0, 1], [1, 1], [0, 0], [1, 0]])
y_train = np.array([1, 0, 0, 1])
weight  = perceptron(x_train, y_train, same_weight = False)
test_arr = new_predict(x_train, y_train, weight)
# Out:
# Epoch: 1
# Epoch: 2
# Epoch: 3
# Epoch: 4
# Epoch: 5
# Epoch: 6
# Epoch: 7
# Epoch: 8
# Epoch: 9
# Epoch: 10
# Epoch: 11
# Epoch: 12
# Epoch: 13
# Epoch: 14
# Epoch: 15
# Epoch: 16
# Epoch: 17
# Epoch: 18
# Epoch: 19
# Epoch: 20
# Epoch: 21
# Epoch: 22
# Epoch: 23
# Epoch: 24
# Epoch: 25
# Epoch: 26
# Epoch: 27
# Epoch: 28
# Epoch: 29
# Epoch: 30
# Epoch: 31
# Epoch: 32
# Epoch: 33
# Epoch: 34
# Epoch: 35
# Epoch: 36
# Epoch: 37
# Epoch: 38
# Epoch: 39
# Epoch: 40
# Epoch: 41
# Epoch: 42
# Succefully Converged:
# Training Accuracy:  0.75
# Prescission Score: 66.66666666666666
# Recall Score :  100.0
# F1 Score :  80.0
# Confusion Matrix :
# [[1 1]
#  [0 2]]
# Classification Report for 3-classes:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.75         4
#    macro avg       0.83      0.75      0.73         4
# weighted avg       0.83      0.75      0.73         4

# %% [markdown]
# # 2. Real Attributes Classification

# %%
def sigmoid(z):
  return 1/(1 + np.exp(-z))

# %%
def real_predict(x_test, y_test, weight):
  # This function will take the weight of the trained model and takes decission based on the threshold value
  # Add Intercept
  # x_test = add_intercept(x_test)
  y_pred = np.ones(y_test.shape[0])
  hypothesis = np.dot(x_test, weight.T)
  # pass to the sigmoid one
  hypothesis = sigmoid(hypothesis)
  for i in range(0, hypothesis.shape[0]):
    if (hypothesis[i]<0.5):
      y_pred[i] = 0
    if (hypothesis[i]>=0.5):
      y_pred[i] = 1
  test_acc = accuracy_score(y_test, y_pred)
  return test_acc

# %%
def add_intercept(x):
  intercept = np.ones((x.shape[0], 1))
  return np.concatenate((intercept, x), axis=1)
def real_perceptron(x_train, y_train, lr = 0.001, same_weight = False):
  # it uses only the threshold function (basic perceptron)
  # add intercept 
  x_train = add_intercept(x_train)
  used_index = []
  weight = np.zeros(x_train.shape[1])# Intialize the weight randomly
  if (same_weight == True): # If we need to do the same weight initilization
    random.seed(10)
  for i in range(0, x_train.shape[1]):
    weight[i] = 0.1 # random.uniform(0, 0.1)
  converged  = True
  x_train, y_train = shuffle(x_train, y_train)  # shuffel the training sample
  index = random.randint(0, x_train.shape[0]-1)
  epoch = 1
  while converged:
    print("Epoch:", epoch)
    hypothesis = np.dot(x_train[index], weight.T)
    if (y_train[index]==1 and hypothesis<0):
      # update the weight using logistic regression
      # w = w + alpha(h(xi)-yi)xi
      weight = weight + x_train[index]*lr*(hypothesis-y_train[index])
    if (y_train[index]==0 and hypothesis>=0):
      # update the weight using logistic regression
      # w = w - x
      weight = weight - x_train[index]*lr*(hypothesis-y_train[index])
    index = random.randint(0, x_train.shape[0]-1)     # pick the random sample
    used_index.append(index)
    if (len(set(used_index)) == x_train.shape[0]):
      # now check what is the accuracy now
      score = real_predict(x_train, y_train, weight)
      print("Score", score)
      if (score*100>=95):
        print("Succefully Converged:")
        converged = False
    epoch = epoch + 1
  return weight

# %%
from sklearn import datasets
iris = datasets.load_iris()

# %%
print("The dictonary keys are associated with data:\n", iris.keys())
print("-"*100)
print("Data:\n", iris['data'])
print("-"*100)
print("Name of the features (Independent features): \n", iris['feature_names'])
print("-"*100)
print("Name of the dependent features: ", iris['target_names'])
print("-"*100)
# Out:
# The dictonary keys are associated with data:
#  dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])
# ----------------------------------------------------------------------------------------------------
# Data:
#  [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
#  [4.6 3.2 1.4 0.2]
#  [5.3 3.7 1.5 0.2]
#  [5.  3.3 1.4 0.2]
#  [7.  3.2 4.7 1.4]
#  [6.4 3.2 4.5 1.5]
#  [6.9 3.1 4.9 1.5]
#  [5.5 2.3 4.  1.3]
#  [6.5 2.8 4.6 1.5]
#  [5.7 2.8 4.5 1.3]
#  [6.3 3.3 4.7 1.6]
#  [4.9 2.4 3.3 1. ]
#  [6.6 2.9 4.6 1.3]
#  [5.2 2.7 3.9 1.4]
#  [5.  2.  3.5 1. ]
#  [5.9 3.  4.2 1.5]
#  [6.  2.2 4.  1. ]
#  [6.1 2.9 4.7 1.4]
#  [5.6 2.9 3.6 1.3]
#  [6.7 3.1 4.4 1.4]
#  [5.6 3.  4.5 1.5]
#  [5.8 2.7 4.1 1. ]
#  [6.2 2.2 4.5 1.5]
#  [5.6 2.5 3.9 1.1]
#  [5.9 3.2 4.8 1.8]
#  [6.1 2.8 4.  1.3]
#  [6.3 2.5 4.9 1.5]
#  [6.1 2.8 4.7 1.2]
#  [6.4 2.9 4.3 1.3]
#  [6.6 3.  4.4 1.4]
#  [6.8 2.8 4.8 1.4]
#  [6.7 3.  5.  1.7]
#  [6.  2.9 4.5 1.5]
#  [5.7 2.6 3.5 1. ]
#  [5.5 2.4 3.8 1.1]
#  [5.5 2.4 3.7 1. ]
#  [5.8 2.7 3.9 1.2]
#  [6.  2.7 5.1 1.6]
#  [5.4 3.  4.5 1.5]
#  [6.  3.4 4.5 1.6]
#  [6.7 3.1 4.7 1.5]
#  [6.3 2.3 4.4 1.3]
#  [5.6 3.  4.1 1.3]
#  [5.5 2.5 4.  1.3]
#  [5.5 2.6 4.4 1.2]
#  [6.1 3.  4.6 1.4]
#  [5.8 2.6 4.  1.2]
#  [5.  2.3 3.3 1. ]
#  [5.6 2.7 4.2 1.3]
#  [5.7 3.  4.2 1.2]
#  [5.7 2.9 4.2 1.3]
#  [6.2 2.9 4.3 1.3]
#  [5.1 2.5 3.  1.1]
#  [5.7 2.8 4.1 1.3]
#  [6.3 3.3 6.  2.5]
#  [5.8 2.7 5.1 1.9]
#  [7.1 3.  5.9 2.1]
#  [6.3 2.9 5.6 1.8]
#  [6.5 3.  5.8 2.2]
#  [7.6 3.  6.6 2.1]
#  [4.9 2.5 4.5 1.7]
#  [7.3 2.9 6.3 1.8]
#  [6.7 2.5 5.8 1.8]
#  [7.2 3.6 6.1 2.5]
#  [6.5 3.2 5.1 2. ]
#  [6.4 2.7 5.3 1.9]
#  [6.8 3.  5.5 2.1]
#  [5.7 2.5 5.  2. ]
#  [5.8 2.8 5.1 2.4]
#  [6.4 3.2 5.3 2.3]
#  [6.5 3.  5.5 1.8]
#  [7.7 3.8 6.7 2.2]
#  [7.7 2.6 6.9 2.3]
#  [6.  2.2 5.  1.5]
#  [6.9 3.2 5.7 2.3]
#  [5.6 2.8 4.9 2. ]
#  [7.7 2.8 6.7 2. ]
#  [6.3 2.7 4.9 1.8]
#  [6.7 3.3 5.7 2.1]
#  [7.2 3.2 6.  1.8]
#  [6.2 2.8 4.8 1.8]
#  [6.1 3.  4.9 1.8]
#  [6.4 2.8 5.6 2.1]
#  [7.2 3.  5.8 1.6]
#  [7.4 2.8 6.1 1.9]
#  [7.9 3.8 6.4 2. ]
#  [6.4 2.8 5.6 2.2]
#  [6.3 2.8 5.1 1.5]
#  [6.1 2.6 5.6 1.4]
#  [7.7 3.  6.1 2.3]
#  [6.3 3.4 5.6 2.4]
#  [6.4 3.1 5.5 1.8]
#  [6.  3.  4.8 1.8]
#  [6.9 3.1 5.4 2.1]
#  [6.7 3.1 5.6 2.4]
#  [6.9 3.1 5.1 2.3]
#  [5.8 2.7 5.1 1.9]
#  [6.8 3.2 5.9 2.3]
#  [6.7 3.3 5.7 2.5]
#  [6.7 3.  5.2 2.3]
#  [6.3 2.5 5.  1.9]
#  [6.5 3.  5.2 2. ]
#  [6.2 3.4 5.4 2.3]
#  [5.9 3.  5.1 1.8]]
# ----------------------------------------------------------------------------------------------------
# Name of the features (Independent features):
#  ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ----------------------------------------------------------------------------------------------------
# Name of the dependent features:  ['setosa' 'versicolor' 'virginica']
# ----------------------------------------------------------------------------------------------------

# %%
# choose x and y 
y_actual = iris['target']
y_actual = list(y_actual)
counter_setosa = 0
counter_versicolor = 0
counter_virginica = 0
for i in range(0,len(y_actual)):
  if(y_actual[i]==0):
    counter_setosa = counter_setosa  + 1 
  if(y_actual[i]==1):
    counter_versicolor = counter_versicolor + 1
  if(y_actual[i]==2):
    counter_virginica = counter_virginica + 1
print("Total no of patterns in setosa class",counter_setosa)
print("Total no of patterns in versicolor class",counter_versicolor)
print("Total no of patterns in virginica class",counter_virginica)
# take only first 100 patterns
for i in range(0,50):
  y_actual.remove(2)
# covert it to an numpy array 
y_actual = np.array(y_actual)
print(y_actual.shape[0])
# Out:
# Total no of patterns in setosa class 50
# Total no of patterns in versicolor class 50
# Total no of patterns in virginica class 50
# 100

# %%
# take only first 100 patterns for the binary classification 
features = list(iris['data'])
print(len(features))
del features[100:]
print(len(features))
features = np.array(features)
print("No of the feature vectors: %d"%features.shape[1])
print("No of the Patterns: %d"%features.shape[0])
# Out:
# 150
# 100
# No of the feature vectors: 4
# No of the Patterns: 100

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(features)
features = scaler.transform(features)

# %%
# Train test validation
from sklearn.model_selection import train_test_split
import random
# train(70%), validation (10%), and test(20%)
X_train, X_test, y_train, y_test = train_test_split(features,y_actual , test_size=0.3, random_state=random.randint(30,100))
X_test, X_validation, y_test, y_validation = train_test_split(X_test, y_test, test_size=0.14, random_state=random.randint(30,100))
print("Size of the train dataset:" + str(X_train.shape))
print("Size of the validation dataset:" + str(X_validation.shape))
print("Size of the test dataset:" + str(X_test.shape))
# Out:
# Size of the train dataset:(70, 4)
# Size of the validation dataset:(5, 4)
# Size of the test dataset:(25, 4)

# %%
def real_test_predict(x_test, y_test, weight):
  # This function will take the weight of the trained model and takes decission based on the threshold value
  # Add Intercept
  x_test = add_intercept(x_test)
  y_pred = np.ones(y_test.shape[0])
  hypothesis = np.dot(x_test, weight.T)
  # pass to the sigmoid one
  hypothesis = sigmoid(hypothesis)
  for i in range(0, hypothesis.shape[0]):
    if (hypothesis[i]<0.5):
      y_pred[i] = 0
    if (hypothesis[i]>=0.5):
      y_pred[i] = 1
  test_acc = accuracy_score(y_test, y_pred)
  return test_acc

# %%
weight  = real_perceptron(X_train, y_train, lr = 0.001, same_weight = False)
# Out:
# Streaming output truncated to the last 5000 lines.
# Score 0.9428571428571428
# Epoch: 22810
# Score 0.9428571428571428
# Epoch: 22811
# Score 0.9428571428571428
# Epoch: 22812
# Score 0.9428571428571428
# Epoch: 22813
# Score 0.9428571428571428
# Epoch: 22814
# Score 0.9428571428571428
# Epoch: 22815
# Score 0.9428571428571428
# Epoch: 22816
# Score 0.9428571428571428
# Epoch: 22817
# Score 0.9428571428571428
# Epoch: 22818
# Score 0.9428571428571428
# Epoch: 22819
# Score 0.9428571428571428
# Epoch: 22820
# Score 0.9428571428571428
# Epoch: 22821
# Score 0.9428571428571428
# Epoch: 22822
# Score 0.9428571428571428
# Epoch: 22823
# Score 0.9428571428571428
# Epoch: 22824
# Score 0.9428571428571428
# Epoch: 22825
# Score 0.9428571428571428
# Epoch: 22826
# Score 0.9428571428571428
# Epoch: 22827
# Score 0.9428571428571428
# Epoch: 22828
# Score 0.9428571428571428
# Epoch: 22829
# Score 0.9428571428571428
# Epoch: 22830
# Score 0.9428571428571428
# Epoch: 22831
# Score 0.9428571428571428
# Epoch: 22832
# Score 0.9428571428571428
# Epoch: 22833
# Score 0.9428571428571428
# Epoch: 22834
# Score 0.9428571428571428
# Epoch: 22835
# Score 0.9428571428571428
# Epoch: 22836
# Score 0.9428571428571428
# Epoch: 22837
# Score 0.9428571428571428
# Epoch: 22838
# Score 0.9428571428571428
# Epoch: 22839
# Score 0.9428571428571428
# Epoch: 22840
# Score 0.9428571428571428
# Epoch: 22841
# Score 0.9428571428571428
# Epoch: 22842
# Score 0.9428571428571428
# Epoch: 22843
# Score 0.9428571428571428
# Epoch: 22844
# Score 0.9428571428571428
# Epoch: 22845
# Score 0.9428571428571428
# Epoch: 22846
# Score 0.9428571428571428
# Epoch: 22847
# Score 0.9428571428571428
# Epoch: 22848
# Score 0.9428571428571428
# Epoch: 22849
# Score 0.9428571428571428
# Epoch: 22850
# Score 0.9428571428571428
# Epoch: 22851
# Score 0.9428571428571428
# Epoch: 22852
# Score 0.9428571428571428
# Epoch: 22853
# Score 0.9428571428571428
# Epoch: 22854
# Score 0.9428571428571428
# Epoch: 22855
# Score 0.9428571428571428
# Epoch: 22856
# Score 0.9428571428571428
# Epoch: 22857
# Score 0.9428571428571428
# Epoch: 22858
# Score 0.9428571428571428
# Epoch: 22859
# Score 0.9428571428571428
# Epoch: 22860
# Score 0.9428571428571428
# Epoch: 22861
# Score 0.9428571428571428
# Epoch: 22862
# Score 0.9428571428571428
# Epoch: 22863
# Score 0.9428571428571428
# Epoch: 22864
# Score 0.9428571428571428
# Epoch: 22865
# Score 0.9428571428571428
# Epoch: 24005
# Score 0.9428571428571428
# Epoch: 24006
# Score 0.9428571428571428
# Epoch: 24007
# Score 0.9428571428571428
# Epoch: 24008
# Score 0.9428571428571428
# Epoch: 24009
# Score 0.9428571428571428
# Epoch: 24010
# Score 0.9428571428571428
# Epoch: 24011
# Score 0.9428571428571428
# Epoch: 24012
# Score 0.9428571428571428
# Epoch: 24013
# Score 0.9428571428571428
# Epoch: 24014
# Score 0.9428571428571428
# Epoch: 24015
# Score 0.9428571428571428
# Epoch: 24016
# Score 0.9428571428571428
# Epoch: 24017
# Score 0.9428571428571428
# Epoch: 24018
# Score 0.9428571428571428
# Epoch: 24019
# Score 0.9428571428571428
# Epoch: 24020
# Score 0.9428571428571428
# Epoch: 24021
# Score 0.9428571428571428
# Epoch: 24022
# Score 0.9428571428571428
# Epoch: 24023
# Score 0.9428571428571428
# Epoch: 24024
# Score 0.9428571428571428
# Epoch: 24025
# Score 0.9428571428571428
# Epoch: 24026
# Score 0.9428571428571428
# Epoch: 24027
# Score 0.9428571428571428
# Epoch: 24028
# Score 0.9428571428571428
# Epoch: 24029
# Score 0.9428571428571428
# Epoch: 24030
# Score 0.9428571428571428
# Epoch: 24031
# Score 0.9428571428571428
# Epoch: 24032
# Score 0.9428571428571428
# Epoch: 24033
# Score 0.9428571428571428
# Epoch: 24034
# Score 0.9428571428571428
# Epoch: 24035
# Score 0.9428571428571428
# Epoch: 24036
# Score 0.9428571428571428
# Epoch: 24037
# Score 0.9428571428571428
# Epoch: 24038
# Score 0.9428571428571428
# Epoch: 24039
# Score 0.9428571428571428
# Epoch: 24040
# Score 0.9428571428571428
# Epoch: 24041
# Score 0.9428571428571428
# Epoch: 24042
# Score 0.9428571428571428
# Epoch: 24043
# Score 0.9428571428571428
# Epoch: 24044
# Score 0.9428571428571428
# Epoch: 24045
# Score 0.9428571428571428
# Epoch: 24046
# Score 0.9428571428571428
# Epoch: 24047
# Score 0.9428571428571428
# Epoch: 24048
# Score 0.9428571428571428
# Epoch: 24049
# Score 0.9428571428571428
# Epoch: 24050
# Score 0.9428571428571428
# Epoch: 24051
# Score 0.9428571428571428
# Epoch: 24052
# Score 0.9428571428571428
# Epoch: 24053
# Score 0.9428571428571428
# Epoch: 24054
# Score 0.9428571428571428
# Epoch: 24055
# Score 0.9428571428571428
# Epoch: 24056
# Score 0.9428571428571428
# Epoch: 24057
# Score 0.9428571428571428
# Epoch: 24058
# Score 0.9428571428571428
# Epoch: 24059
# Score 0.9428571428571428
# Epoch: 24060
# Score 0.9428571428571428
# Epoch: 24061
# Score 0.9428571428571428
# Epoch: 24062
# Score 0.9428571428571428
# Epoch: 24063
# Score 0.9428571428571428
# Epoch: 24064
# Score 0.9428571428571428
# Epoch: 24065
# Score 0.9428571428571428
# Epoch: 24066
# Score 0.9428571428571428
# Epoch: 24067
# Score 0.9428571428571428
# Epoch: 24068
# Score 0.9428571428571428
# Epoch: 24069
# Score 0.9428571428571428
# Epoch: 24070
# Score 0.9428571428571428
# ...
# Epoch: 25291
# Score 0.9428571428571428
# Epoch: 25292
# Score 0.9428571428571428
# Epoch: 25293
# Score 0.9428571428571428
# Epoch: 25294
# Score 0.9428571428571428
# Epoch: 25295
# Score 0.9428571428571428
# Epoch: 25296
# Score 0.9428571428571428
# Epoch: 25297
# Score 0.9428571428571428
# Epoch: 25298
# Score 0.9428571428571428
# Epoch: 25299
# Score 0.9428571428571428
# Epoch: 25300
# Score 0.9428571428571428
# Epoch: 25301
# Score 0.9428571428571428
# Epoch: 25302
# Score 0.9428571428571428
# Epoch: 25303
# Score 0.9428571428571428
# Epoch: 25304
# Score 0.9428571428571428
# Epoch: 25305
# Score 0.9428571428571428
# Epoch: 25306
# Score 0.9428571428571428
# Epoch: 25307
# Score 0.9428571428571428
# Epoch: 25308
# Score 0.9571428571428572
# Succefully Converged:

# %%
weight
# Out:
# array([-0.04880595,  0.05180853,  0.00071577,  0.08173826,  0.08483168])

# %%
acc = real_test_predict(X_test, y_test, weight)

# %%
print("Test Accuracy:" ,acc*100)
# Out:
# Test Accuracy: 92.0

# %% [markdown]
# # Multi Class Classification

# %%
def sigmoid(z):
  return 1/(1 + np.exp(-z))

# %%
def multi_predict(x_test, y_test, weight):
  # This function will take the weight of the trained model and takes decission based on the threshold value
  # Add Intercept
  # x_test = add_intercept(x_test)
  y_pred = np.ones(y_test.shape[0])
  hypothesis = np.dot(x_test, weight.T)
  # pass to the sigmoid one
  hypothesis = sigmoid(hypothesis)
  for i in range(0, hypothesis.shape[0]):
    if (hypothesis[i]<0.5):
      y_pred[i] = 0
    if (hypothesis[i]>=0.5):
      y_pred[i] = 1
  test_acc = accuracy_score(y_test, y_pred)
  return test_acc

# %%
def add_intercept(x):
  intercept = np.ones((x.shape[0], 1))
  return np.concatenate((intercept, x), axis=1)
def multi_perceptron(x_train, y_train, lr = 0.001, same_weight = False):
  # it uses only the threshold function (basic perceptron)
  # add intercept 
  x_train = add_intercept(x_train)
  used_index = []
  weight = np.zeros(x_train.shape[1])# Intialize the weight randomly
  if (same_weight == True): # If we need to do the same weight initilization
    random.seed(10)
  for i in range(0, x_train.shape[1]):
    weight[i] = 0.1 # random.uniform(0, 0.1)
  converged  = True
  x_train, y_train = shuffle(x_train, y_train)  # shuffel the training sample
  index = random.randint(0, x_train.shape[0]-1)
  epoch = 1
  while converged:
    print("Epoch:", epoch)
    hypothesis = np.dot(x_train[index], weight.T)
    if (y_train[index]==1 and hypothesis<0):
      # update the weight using logistic regression
      # w = w + alpha(h(xi)-yi)xi
      weight = weight + x_train[index]*lr*(hypothesis-y_train[index])
    if (y_train[index]==0 and hypothesis>=0):
      # update the weight using logistic regression
      # w = w - x
      weight = weight - x_train[index]*lr*(hypothesis-y_train[index])
    index = random.randint(0, x_train.shape[0]-1)     # pick the random sample
    used_index.append(index)
    if (len(set(used_index)) == x_train.shape[0]):
      # now check what is the accuracy now
      score = real_predict(x_train, y_train, weight)
      print("Score", score)
      if (score*100>=95):
        print("Succefully Converged:")
        converged = False
    epoch = epoch + 1
  return weight
