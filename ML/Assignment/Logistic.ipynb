# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# %%
p = np.arange(0,1,0.01)

# %%
plt.plot(p, -1*np.log(p))
# Out:
# <ipython-input-11-524e8e242bbc>:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(p, -1*np.log(p))

# %%
plt.plot(p,-1*np.log(1-p))

# %%
plt.plot(p,-1*np.log(p),'b')
plt.plot(p,-1*np.log(1-p),'g')
plt.show()
# Out:
# <ipython-input-20-c9a3ec23c22a>:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(p,-1*np.log(p),'b')

# %%
plt.plot(p,1/(1+np.exp(-p)))
